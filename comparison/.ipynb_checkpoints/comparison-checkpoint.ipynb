# %%
from skimage.measure import compare_ssim, compare_mse
from skimage import img_as_float
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

ref = Image.open('../images/reference/reference_scene3_256x256_5120spp.png').convert("RGB")
ref_array = np.array(ref)

img = []
q_equally_sized = []
for i in range(128):
    stringa = '../images/png/DDQN_scene3_lr00000800_struct500-700_400-400_600-700_eps7500_QLEARNING_ep7500_equallysized-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    q_equally_sized.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(q_equally_sized)

img = []
q_notequally_sized = []
for i in range(128):
    stringa = '../images/png/DDQN_scene3_lr00000800_struct500-700_400-400_600-700_eps7500_QLEARNING_ep7500-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    q_notequally_sized.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(q_notequally_sized)

img = []
pg_direct = []
for i in range(128):
    stringa = '../images/png/Q_path_guiding_scene3_strategy1_eps7500_2pi-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    pg_direct.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(pg_direct)

img = []
pg_cumulative = []
for i in range(128):
    stringa = '../images/png/Q_path_guiding_scene3_strategy2_cumulative_eps7500-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    pg_cumulative.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(pg_cumulative)

img = []
dqn_notequally_sized = []
for i in range(128):
    stringa = '../images/png/DDQN_scene3_lr00000800_struct500-700_400-400_600-700_eps7500_DQN_128-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    dqn_notequally_sized.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(dqn_notequally_sized)

img = []
cos_new = []
for i in range(128):
    stringa = 'D:\Documents\eclipse-workspace\SmallPT-QPG\images\png\scene3-cos-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    cos_new.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(cos_new)

img = []
q_notequally_sized_new = []
for i in range(128):
    stringa = 'D:\Documents\eclipse-workspace\SmallPT-QPG\images\png\scene3-QLearning-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    q_notequally_sized_new.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(q_notequally_sized_new)

img = []
q_notequally_sized_new_eps05 = []
for i in range(127):
    stringa = 'D:\Documents\eclipse-workspace\SmallPT-QPG\images\png\scene3-QLearning-eps05-'+str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    q_notequally_sized_new_eps05.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(q_notequally_sized_new_eps05)

img = []
qpathguiding_new_eps05 = []
for i in range(112):
    stringa = 'D:\Documents\eclipse-workspace\SmallPT-QPG\images\png\scene3-QPG-eps05-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    qpathguiding_new_eps05.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(qpathguiding_new_eps05)

plt.xlabel("SPP",fontweight='bold', fontsize='large')
plt.ylabel("SSIM",fontweight='bold', fontsize='large')
plt.legend(["[1] Q-learning, equally-sized action space, delay", "[2] Q-learning, improved action space, delay", "[3] Adapted Path Guiding, no delay","[4] Q-learning, improved action space, no delay",
            "[5] Dueling DQN, improved action space, delay", '[6] Cosine-weighted importance sampling new', '[7] Q-learning, improved action space, delay NEW,epsilon=0',
            '[8] Q-learning, improved action space, delay NEW,epsilon=0.5', '[9] Q Path Guiding, NEW'],bbox_to_anchor=(1.04, 1), loc='upper left', ncol=1)
plt.show()

############################################################################################################################################################################################################
# MSE

img = []
mse_q_equally_sized = []
for i in range(128):
    stringa = '../images/png/DDQN_scene3_lr00000800_struct500-700_400-400_600-700_eps7500_QLEARNING_ep7500_equallysized-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_q_equally_sized.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_q_equally_sized)

img = []
mse_q_notequally_sized = []
for i in range(128):
    stringa = '../images/png/DDQN_scene3_lr00000800_struct500-700_400-400_600-700_eps7500_QLEARNING_ep7500-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_q_notequally_sized.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_q_notequally_sized)

img = []
mse_pg_direct = []
for i in range(128):
    stringa = '../images/png/Q_path_guiding_scene3_strategy1_eps7500_2pi-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_pg_direct.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_pg_direct)

img = []
mse_pg_cumulative = []
for i in range(128):
    stringa = '../images/png/Q_path_guiding_scene3_strategy2_cumulative_eps7500-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_pg_cumulative.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_pg_cumulative)

img = []
mse_dqn_notequally_sized = []
for i in range(128):
    stringa = '../images/png/DDQN_scene3_lr00000800_struct500-700_400-400_600-700_eps7500_DQN_128-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_dqn_notequally_sized.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_dqn_notequally_sized)

img = []
mse_cos_new = []
for i in range(128):
    stringa = 'D:\Documents\eclipse-workspace\SmallPT-QPG\images\png\scene3-cos-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_cos_new.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_cos_new)

img = []
mse_q_notequally_sized_new = []
for i in range(128):
    stringa = 'D:\Documents\eclipse-workspace\SmallPT-QPG\images\png\scene3-QLearning-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_q_notequally_sized_new.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_q_notequally_sized_new)

img = []
mse_q_notequally_sized_new_eps05 = []
for i in range(127):
    stringa = 'D:\Documents\eclipse-workspace\SmallPT-QPG\images\png\scene3-QLearning-eps05-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_q_notequally_sized_new_eps05.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_q_notequally_sized_new_eps05)

img = []
qpathguiding_new_eps05 = []
for i in range(112):
    stringa = 'D:\Documents\eclipse-workspace\SmallPT-QPG\images\png\scene3-QPG-eps05-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    qpathguiding_new_eps05.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(qpathguiding_new_eps05)

plt.xlabel("SPP",fontweight='bold', fontsize='large')
plt.ylabel("MSE",fontweight='bold', fontsize='large')

plt.legend(["[1] Q-learning, equally-sized action space, delay", "[2] Q-learning, improved action space, delay", "[3] Adapted Path Guiding, no delay","[4] Q-learning, improved action space, no delay", "[5] Dueling DQN, improved action space, delay", '[6] Cosine-weighted importance sampling new', '[7] Q-learning, improved action space, delay NEW, epsilon=0', '[8] Q-learning, improved action space, delay NEW,epsilon=0.5'],bbox_to_anchor=(1.04, 1), loc='upper left', ncol=1)
plt.show()
