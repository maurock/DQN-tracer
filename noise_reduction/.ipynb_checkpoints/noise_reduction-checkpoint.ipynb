# %% [markdown]
# # SCENE 1

# %%
from skimage.measure import compare_ssim, compare_mse
from skimage import img_as_float
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

'''
ref = Image.open('scenedqn-5120spp-explicit-256.png').convert("RGB")
ref_array = np.array(ref)
img = []
ssim_array_dqn = []
for i in range(30):
    stringa = 'py-smallpt-10000L3500-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-32spp-256-noisereduction-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_dqn)
'''

ref = Image.open('scenedqn-5120spp-explicit-256.png').convert("RGB")
ref_array = np.array(ref)

img = []
ssim_array_dqn = []
for i in range(30):
    stringa = 'py-smallpt-10000L3500-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-32spp-256-depth6-noisereduction-AGAIN-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_dqn)

img = []
ssim_array_dqn_NOTARGET = []
for i in range(30):
    stringa = 'py-smallpt-10000L2000-72actions-lineareps-lr00001-1000nnx4-KERNEL16-NO_targetnet-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_NOTARGET.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_dqn_NOTARGET)

'''
ssim_array_q = []
img = []
for i in range(30):
    stringa = 'scenedqn-qlearning-noisereduction-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_q.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_q)
'''
ssim_array_q = []
img = []
for i in range(30):
    stringa = 'scenedqn-qlearning-depth6-noisereduction-AGAIN-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_q.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_q)


ssim_array_impsampl = []
img = []
for i in range(30):
    stringa = 'scenedqn-importancesampling-noisereduction-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_impsampl.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_impsampl)

ssim_array_maxAction2 = []
img = []
for i in range(30):
    stringa = 'py-smallpt-lr00001-relu-nnx4-maxAction2-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_maxAction2.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_maxAction2)

ssim_array_doubleNet_maxAction = []
img = []
for i in range(13):
    stringa = 'py-smallpt-lr00001-doubleNet-1000nnx4-do_action_avg-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_doubleNet_maxAction.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
#plt.plot(ssim_array_doubleNet_maxAction)

ssim_array_ADQN_1 = []
img = []
for i in range(31):
    stringa = 'py-smallpt-lr00001-relu-1000nnx4-k5-no_target-config1-ADQN-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_ADQN_1.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
#plt.plot(ssim_array_ADQN_1)

ssim_array_Q_newaction = []
img = []
for i in range(32):
    stringa = 'scenedqn-qlearning-32SPP-NewAction2-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_Q_newaction.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_Q_newaction)


plt.xlabel("SPP", fontweight='bold', fontsize='large')
plt.ylabel("SSIM", fontweight='bold', fontsize='large')
plt.legend(["Deep Q-Learning","Deep Q-Learning NO TARGET","Q-Learning","Cosine", "Max Action 2", "Q Learning new action"], fontsize='large')
plt.savefig("scene1-ssim.png")
plt.show()


# MSE
'''
img = []
mse_array_dqn = []
for i in range(30):
    stringa = 'py-smallpt-10000L3500-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-32spp-256-noisereduction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_dqn)
'''

img = []
mse_array_dqn = []
for i in range(30):
    stringa = 'py-smallpt-10000L3500-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-32spp-256-depth6-noisereduction-AGAIN-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_dqn)

img = []
mse_array_dqn_NOTARGET = []
for i in range(30):
    stringa = 'py-smallpt-10000L2000-72actions-lineareps-lr00001-1000nnx4-KERNEL16-NO_targetnet-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn_NOTARGET.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_dqn_NOTARGET)


'''
img = []
mse_array_q = []
for i in range(30):
    stringa = 'scenedqn-qlearning-noisereduction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_q.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_q)
'''
img = []
mse_array_q = []
for i in range(30):
    stringa = 'scenedqn-qlearning-depth6-noisereduction-AGAIN-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_q.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_q)

img = []
mse_array_impsampl = []
for i in range(30):
    stringa = 'scenedqn-importancesampling-noisereduction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_impsampl.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_impsampl)

img = []
mse_array_maxAction2 = []
for i in range(30):
    stringa = 'py-smallpt-lr00001-relu-nnx4-maxAction2-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_maxAction2.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_maxAction2)

img = []
mse_array_doubleNet_maxAction = []
for i in range(13):
    stringa = 'py-smallpt-lr00001-doubleNet-1000nnx4-do_action_avg-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_doubleNet_maxAction.append((compare_mse(img_as_float(ref_array), img[i])))
#plt.plot(mse_array_doubleNet_maxAction)

img = []
mse_array_ADQN_1 = []
for i in range(30):
    stringa = 'py-smallpt-lr00001-relu-1000nnx4-k5-no_target-config1-ADQN-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_ADQN_1.append((compare_mse(img_as_float(ref_array), img[i])))
#plt.plot(mse_array_ADQN_1)

img = []
mse_array_Q_newaction = []
for i in range(32):
    stringa = 'scenedqn-qlearning-32SPP-NewAction2-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_Q_newaction.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_Q_newaction)

plt.xlabel("SPP", fontweight='bold', size='large')
plt.ylabel("MSE", fontweight='bold', fontsize='large')
plt.legend(["Deep Q-Learning","Deep Q-Learning NO TARGET","Q-Learning","Cosine", "Max Action 2"],fontsize='large')
#plt.savefig("scene1-mse.png")

# %% [markdown]
# # SCENE 1: TARGET vs NO-TARGET

# %%
img = []
ssim_array_dqn = []
for i in range(30):
    stringa = 'py-smallpt-10000L3500-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-32spp-256-depth6-noisereduction-AGAIN-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_dqn)

img = []
ssim_array_dqn_NOTARGET = []
for i in range(30):
    stringa = 'py-smallpt-10000L2000-72actions-lineareps-lr00001-1000nnx4-KERNEL16-NO_targetnet-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_NOTARGET.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_dqn_NOTARGET)

plt.xlabel("SPP", fontweight='bold', fontsize='large')
plt.ylabel("SSIM", fontweight='bold', fontsize='large')
plt.legend(["Deep Q-Learning, Target Network","Deep Q-Learning, No Target Network"], fontsize='large')
plt.savefig("scene1-ssim-targetvsnotarget.png")
plt.show()



img = []
mse_array_dqn = []
for i in range(30):
    stringa = 'py-smallpt-10000L3500-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-32spp-256-depth6-noisereduction-AGAIN-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_dqn)

img = []
mse_array_dqn_NOTARGET = []
for i in range(30):
    stringa = 'py-smallpt-10000L2000-72actions-lineareps-lr00001-1000nnx4-KERNEL16-NO_targetnet-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn_NOTARGET.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_dqn_NOTARGET)


plt.xlabel("SPP", fontweight='bold', size='large')
plt.ylabel("MSE", fontweight='bold', fontsize='large')
plt.legend(["Deep Q-Learning","Deep Q-Learning NO TARGET","Q-Learning","Cosine"],fontsize='large')
plt.savefig("scene1-mse-targetvsnotarget.png")

# %% [markdown]
# # Scene 1 - DQN 200 vs 500 vs 1000

# %%
ref = Image.open('scenedqn-explicitlight-5120spp-128.png').convert("RGB")
ref_array = np.array(ref)

img = []
ssim_array_dqn_200 = []
for i in range(32):
    stringa = '10000L3500-72actions-lineareps-lr00001-200nnx4-KERNEL16-targetnet-noisereduction-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_200.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_dqn_200)

img = []
ssim_array_dqn_500 = []
for i in range(32):
    stringa = '10000L3500-72actions-lineareps-lr00001-500nnx4-KERNEL16-targetnet-noisereduction-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_500.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_dqn_500)

img = []
ssim_array_dqn_1000 = []
for i in range(32):
    stringa = '10000L3500-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-noisereduction-128-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_1000.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_dqn_1000)

plt.xlabel("SPP", fontweight='bold', fontsize='large')
plt.ylabel("SSIM", fontweight='bold', fontsize='large')
plt.legend(["Deep Q-Learning, 200 Neurons","Deep Q-Learning, 500 Neurons","Deep Q-Learning, 1000 Neurons"], fontsize='large')
plt.savefig("scene1-ssim-200vs500vs1000.png")
plt.show()



img = []
ssim_array_dqn_200 = []
for i in range(32):
    stringa = '10000L3500-72actions-lineareps-lr00001-200nnx4-KERNEL16-targetnet-noisereduction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    ssim_array_dqn_200.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(ssim_array_dqn_200)

img = []
ssim_array_dqn_500 = []
for i in range(32):
    stringa = '10000L3500-72actions-lineareps-lr00001-500nnx4-KERNEL16-targetnet-noisereduction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    ssim_array_dqn_500.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(ssim_array_dqn_500)

img = []
ssim_array_dqn_1000 = []
for i in range(32):
    stringa = '10000L3500-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-noisereduction-128-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    ssim_array_dqn_1000.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(ssim_array_dqn_1000)

plt.xlabel("SPP", fontweight='bold', fontsize='large')
plt.ylabel("MSE", fontweight='bold', fontsize='large')
plt.legend(["Deep Q-Learning, 200 Neurons","Deep Q-Learning, 500 Neurons","Deep Q-Learning, 1000 Neurons"], fontsize='large')
plt.savefig("scene1-mse-200vs500vs1000.png")
plt.show()

# %% [markdown]
# # SCENE 2

# %%
from skimage.measure import compare_ssim, compare_mse
from skimage import img_as_float
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

ref = Image.open('scenedqn2-5120spp-explicit-256.png').convert("RGB")
ref_array = np.array(ref)

'''
img = []
ssim_array_dqn = []
for i in range(32):
    stringa = 'py-smallpt2-10000L2000-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-32spp-256-noisereduction-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_dqn)
print("DQN, SSIM: ", compare_ssim(ref_array, np.array(img[31]), multichannel = True))
'''

img = []
ssim_array_dqn = []
for i in range(32):
    stringa = 'py-smallpt2-10000L2000-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-32spp-256-depth6-noisereduction-AGAIN-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_dqn)
print("DQN, SSIM: ", compare_ssim(ref_array, np.array(img[31]), multichannel = True))



'''
ssim_array_q = []
img = []
for i in range(32):
    stringa = 'scenedqn2-qlearning-noisereduction-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_q.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_q)
print("Q, SSIM: ", compare_ssim(ref_array, np.array(img[31]), multichannel = True))
'''

ssim_array_q = []
img = []
for i in range(32):
    stringa = 'scenedqn2-qlearning-depth6-noisereduction-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_q.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_q)
print("Q, SSIM: ", compare_ssim(ref_array, np.array(img[31]), multichannel = True))

ssim_array_impsampl = []
img = []
for i in range(32):
    stringa = 'scenedqn2-importancesampling-noisereduction-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_impsampl.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_impsampl)


plt.xlabel("SPP", fontweight='bold', fontsize='large')
plt.ylabel("SSIM",fontweight='bold', fontsize='large')
plt.legend(["Deep Q-Learning","Q-Learning","Cosine"],fontsize='large')
plt.savefig("scene2-ssim.png")
plt.show()


# MSE

'''
img = []
mse_array_dqn = []
for i in range(32):
    stringa = 'py-smallpt2-10000L2000-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-32spp-256-noisereduction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn.append((compare_mse(img_as_float(ref_array), img_as_float(img[i]))))
plt.plot(mse_array_dqn)
print("DQN, MSE: ",compare_mse(img_as_float(ref_array), img_as_float(img[31])))
'''

img = []
mse_array_dqn = []
for i in range(32):
    stringa = 'py-smallpt2-10000L2000-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-32spp-256-depth6-noisereduction-AGAIN-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn.append((compare_mse(img_as_float(ref_array), img_as_float(img[i]))))
plt.plot(mse_array_dqn)
print("DQN, MSE: ",compare_mse(img_as_float(ref_array), img_as_float(img[31])))

'''
img = []
mse_array_q = []
for i in range(32):
    stringa = 'scenedqn2-qlearning-noisereduction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_q.append((compare_mse(img_as_float(ref_array), img_as_float(img[i]))))
plt.plot(mse_array_q)
print("Q, MSE: ", compare_mse(img_as_float(ref_array), img_as_float(img[31])))
'''
img = []
mse_array_q = []
for i in range(32):
    stringa = 'scenedqn2-qlearning-depth6-noisereduction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_q.append((compare_mse(img_as_float(ref_array), img_as_float(img[i]))))
plt.plot(mse_array_q)
print("Q, MSE: ", compare_mse(img_as_float(ref_array), img_as_float(img[31])))



img = []
mse_array_impsampl = []
for i in range(32):
    stringa = 'scenedqn2-importancesampling-noisereduction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_impsampl.append((compare_mse(img_as_float(ref_array), img_as_float(img[i]))))

plt.plot(mse_array_impsampl)
plt.xlabel("SPP", fontweight='bold', fontsize='large')
plt.ylabel("MSE", fontweight='bold', fontsize='large')
plt.legend(["Deep Q-Learning","Q-Learning","Cosine"],fontsize='large')

plt.savefig("scene2-mse.png")
plt.show()
# Out:
# DQN, SSIM:  0.0891748118890266
# Q, SSIM:  0.07562471027220176
# DQN, MSE:  0.026529425797394632
# Q, MSE:  0.026054595904244554

# %% [markdown]
# # SCENE 3

# %%
from skimage.measure import compare_ssim, compare_mse
from skimage import img_as_float
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

ref = Image.open('scenedqn3-5120spp-explicit-256.png').convert("RGB")
ref_array = np.array(ref)

img = []
ssim_array_dqn = []
for i in range(32):
    stringa = 'py-smallpt3-10000L2000-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-32spp-256-depth6-noisereduction-AGAIN-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_dqn)

img = []
ssim_array_dqn_1500 = []
for i in range(32):
    stringa = 'py-smallpt-3-10000L2000-72actions-lineareps-lr00001-1500nnx4-KERNEL16-targetnet-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_1500.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
#plt.plot(ssim_array_dqn_1500)


'''
ssim_array_q = []
img = []
for i in range(32):
    stringa = 'scenedqn3-qlearning-noisereduction-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_q.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_q)
'''
ssim_array_q = []
img = []
for i in range(32):
    stringa = 'scenedqn3-qlearning-depth6-noisereduction-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_q.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_q)

ssim_array_impsampl = []
img = []
for i in range(32):
    stringa = 'scenedqn3-importancesampling-noisereduction-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_impsampl.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_impsampl)

ssim_array_dqn_doublekernel = []
img = []
for i in range(32):
    stringa = 'py-smallpt-doublekernel-TEST.ppm' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_doublekernel.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
#plt.plot(ssim_array_dqn_doublekernel)

ssim_array_dqn_doublekernel_000001 = []
img = []
for i in range(30):
    stringa = 'py-smallpt-doublekernel-lr000001-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_doublekernel_000001.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
#plt.plot(ssim_array_dqn_doublekernel_000001)

ssim_array_dqn_sigmoid_notall = []
img = []
for i in range(27):
    stringa = 'py-smallpt3-lr00001-1000xnn4-sigmoid.ppm' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_sigmoid_notall.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
#plt.plot(ssim_array_dqn_sigmoid_notall)

img = []
ssim_array_dqn_relu_decaying18 = []
for i in range(32):
    stringa = 'py-smallpt3-lr00001-1000nnx4-relu-decayinglr1.8' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_relu_decaying18.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
#plt.plot(ssim_array_dqn_relu_decaying18)

img = []
ssim_array_dqn_relu_maxAction = []
for i in range(32):
    stringa = 'py-smallpt3-lr00001-relu-nnx4-maxAction-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_relu_maxAction.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
#plt.plot(ssim_array_dqn_relu_maxAction)

img = []
ssim_array_dqn_relu_maxAction_cosine1 = []
for i in range(8):
    stringa = 'py-smallpt3-lr00001-relu-nnx4-maxAction-cosine-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_relu_maxAction_cosine1.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
#plt.plot(ssim_array_dqn_relu_maxAction_cosine1)

img = []
ssim_array_dqn_relu_maxAction_cosine2 = []
for i in range(8):
    stringa = 'py-smallpt3-lr00001-relu-nnx4-maxAction-cosine2-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_relu_maxAction_cosine2.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
#plt.plot(ssim_array_dqn_relu_maxAction_cosine2)

img = []
ssim_array_dqn_relu_maxAction_cosine3 = []
for i in range(31):
    stringa = 'py-smallpt3-lr00001-relu-nnx4-maxAction-cosine3-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_relu_maxAction_cosine3.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
#plt.plot(ssim_array_dqn_relu_maxAction_cosine3)

img = []
ssim_array_dqn_relu_maxAction2 = []
for i in range(32):
    stringa = 'py-smallpt3-lr00001-relu-nnx4-maxAction2-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_relu_maxAction2.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_dqn_relu_maxAction2)
'''
img = []
ssim_array_q_2pi = []
for i in range(32):
    stringa = 'scenedqn3-qlearning-32SPP-2pi-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_q_2pi.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
#plt.plot(ssim_array_q_2pi)
'''

img = []
ssim_array_dqn_MaxAction2_epochs2 = []
for i in range(32):
    stringa = 'py-smallpt-lr00001-relu-nnx4-maxAction2-epochs2-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_MaxAction2_epochs2.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
#plt.plot(ssim_array_dqn_MaxAction2_epochs2)


img = []
ssim_array_q_newaction = []
for i in range(32):
    stringa = 'scenedqn3-qlearning-32SPP-NewAction-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_q_newaction.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_q_newaction)

img = []
ssim_array_q_newaction2 = []
for i in range(32):
    stringa = 'scenedqn3-qlearning-32SPP-NewAction2-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_q_newaction2.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
#plt.plot(ssim_array_q_newaction2)

img = []
ssim_array_dqn_maxACtion_newAction = []
for i in range(32):
    stringa = 'py-smallpt-lr00001-relu-nnx4-newAction-maxAction-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_maxACtion_newAction.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
#plt.plot(ssim_array_dqn_maxACtion_newAction)
         
img = []
ssim_array_dqn_maxACtion_newAction_lr0001 = []
for i in range(27):
    stringa = 'py-smallpt-lr0001-relu-nnx4-newAction-maxAction-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_maxACtion_newAction_lr0001.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
#plt.plot(ssim_array_dqn_maxACtion_newAction_lr0001)

img = []
ssim_array_dqn_maxACtion_newAction_lr000001 = []
for i in range(32):
    stringa = 'py-smallpt-lr000001-relu-nnx4-newAction-maxAction-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_maxACtion_newAction_lr000001.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_dqn_maxACtion_newAction_lr000001)

img = []
ssim_array_dqn_relu_newAction_maxAction_eps5000 = []
for i in range(32):
    stringa = 'py-smallpt-lr00001-relu-nnx4-newAction-maxAction-eps5000-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_relu_newAction_maxAction_eps5000.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_dqn_relu_newAction_maxAction_eps5000)

img = []
ssim_array_DDQN_relu_newAction_maxAction_eps5000_lr000001 = []
for i in range(32):
    stringa = 'py-smallpt-lr000001-relu-nnx4-newAction-maxAction-eps5000-DDQN-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_DDQN_relu_newAction_maxAction_eps5000_lr000001.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_DDQN_relu_newAction_maxAction_eps5000_lr000001)

img = []
ssim_array_relu_newAction_maxAction_eps5000_lr00001_DDQN_struct2 = []
for i in range(20):
    stringa = 'py-smallpt-lr00001-relu-nnx4-newAction-maxAction-eps5000-DDQN_struct2-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_relu_newAction_maxAction_eps5000_lr00001_DDQN_struct2.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
#plt.plot(ssim_array_relu_newAction_maxAction_eps5000_lr00001_DDQN_struct2)

img = []
ssim_array_dqn_relu_newAction_maxAction_eps5000_lr000001 = []
for i in range(27):
    stringa = 'py-smallpt-lr000001-relu-nnx4-newAction-maxAction-eps5000-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_relu_newAction_maxAction_eps5000_lr000001.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
#plt.plot(ssim_array_dqn_relu_newAction_maxAction_eps5000_lr000001)

img = []
ssim_array_relu_newAction_maxAction_eps5000_lr00001_DDQN_struct4 = []
for i in range(32):
    stringa = 'py-smallpt-lr00001-relu-nnx4-newAction-maxAction-eps5000-DDQN_struct4-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_relu_newAction_maxAction_eps5000_lr00001_DDQN_struct4.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_relu_newAction_maxAction_eps5000_lr00001_DDQN_struct4)
'''
img = []
ssim_array_relu_newAction_maxAction_eps5000_lr000001_DDQN_struct4 = []
for i in range(20):
    stringa = 'py-smallpt-lr000001-relu-nnx4-newAction-maxAction-eps5000-DDQN_struct4-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_relu_newAction_maxAction_eps5000_lr000001_DDQN_struct4.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_relu_newAction_maxAction_eps5000_lr000001_DDQN_struct4)
'''
plt.xlabel("SPP", fontweight='bold', fontsize='large')
plt.ylabel("SSIM", fontweight='bold', fontsize='large')
#plt.legend(["Deep Q-Learning 1000","Deep Q-Learning 1500","Q-Learning","Cosine","Deep Q-Learning Double Kernel","Deep Q-Learning Double Kernel lr000001", "Sigmoid not all", "Decaying linear 1.8"],fontsize='large',bbox_to_anchor=(1.04, 1), loc='upper left', ncol=1))
plt.legend(["Deep Q-Learning 1000","Q-Learning","Cosine", "Max Action 2", "Q-Learning New action", "DQN newaction maxAction 000001lr", "DQN new action eps5000 lr00001", "DDQN eps5000 lr00001","DDQN eps5000 lr00001 struct4", "same o000001" ],fontsize='large',bbox_to_anchor=(1.04, 1), loc='upper left', ncol=1)
#plt.savefig("scene3-ssim.png")

plt.show()


# MSE
'''
img = []
mse_array_dqn = []
for i in range(32):
    stringa = 'py-smallpt3-10000L2000-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-32spp-256-noisereduction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_dqn)
'''
img = []
mse_array_dqn = []
for i in range(32):
    stringa = 'py-smallpt3-10000L2000-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-32spp-256-depth6-noisereduction-AGAIN-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_dqn)

img = []
mse_array_dqn_1500 = []
for i in range(32):
    stringa = 'py-smallpt-3-10000L2000-72actions-lineareps-lr00001-1500nnx4-KERNEL16-targetnet-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn_1500.append((compare_mse(img_as_float(ref_array), img[i]))) 
#plt.plot(mse_array_dqn_1500)

'''
img = []
mse_array_q = []
for i in range(32):
    stringa = 'scenedqn3-qlearning-noisereduction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_q.append((compare_mse(img_as_float(ref_array), img[i]))) 
plt.plot(mse_array_q)
'''
img = []
mse_array_q = []
for i in range(32):
    stringa = 'scenedqn3-qlearning-depth6-noisereduction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_q.append((compare_mse(img_as_float(ref_array), img[i]))) 
plt.plot(mse_array_q)

img = []
mse_array_impsampl = []
for i in range(32):
    stringa = 'scenedqn3-importancesampling-noisereduction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_impsampl.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_impsampl)

img = []
mse_array_dqn_doublekernel = []
for i in range(32):
    stringa = 'py-smallpt-doublekernel-TEST.ppm' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn_doublekernel.append((compare_mse(img_as_float(ref_array), img[i])))
#plt.plot(mse_array_dqn_doublekernel)

img = []
mse_array_dqn_doublekernel_000001 = []
for i in range(30):
    stringa = 'py-smallpt-doublekernel-lr000001-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn_doublekernel_000001.append((compare_mse(img_as_float(ref_array), img[i])))
#plt.plot(mse_array_dqn_doublekernel_000001)

img = []
mse_array_dqn_sigmoid_notall = []
for i in range(27):
    stringa = 'py-smallpt3-lr00001-1000xnn4-sigmoid.ppm' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn_sigmoid_notall.append((compare_mse(img_as_float(ref_array), img[i])))
#plt.plot(mse_array_dqn_sigmoid_notall)

img = []
mse_array_dqn_relu_decaying18 = []
for i in range(32):
    stringa = 'py-smallpt3-lr00001-1000nnx4-relu-decayinglr1.8' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn_relu_decaying18.append((compare_mse(img_as_float(ref_array), img[i])))
#plt.plot(mse_array_dqn_relu_decaying18)

img = []
mse_array_dqn_relu_maxAction = []
for i in range(32):
    stringa = 'py-smallpt3-lr00001-relu-nnx4-maxAction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn_relu_maxAction.append((compare_mse(img_as_float(ref_array), img[i])))
#plt.plot(mse_array_dqn_relu_maxAction)

img = []
mse_array_dqn_relu_maxAction_cosine1 = []
for i in range(8):
    stringa = 'py-smallpt3-lr00001-relu-nnx4-maxAction-cosine-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn_relu_maxAction_cosine1.append((compare_mse(img_as_float(ref_array), img[i])))
#plt.plot(mse_array_dqn_relu_maxAction_cosine1)

img = []
mse_array_dqn_relu_maxAction_cosine2 = []
for i in range(8):
    stringa = 'py-smallpt3-lr00001-relu-nnx4-maxAction-cosine2-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn_relu_maxAction_cosine2.append((compare_mse(img_as_float(ref_array), img[i])))
#plt.plot(mse_array_dqn_relu_maxAction_cosine2)

img = []
mse_array_dqn_relu_maxAction_cosine3 = []
for i in range(31):
    stringa = 'py-smallpt3-lr00001-relu-nnx4-maxAction-cosine3-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn_relu_maxAction_cosine3.append((compare_mse(img_as_float(ref_array), img[i])))
#plt.plot(mse_array_dqn_relu_maxAction_cosine3)

img = []
mse_array_dqn_relu_maxAction2 = []
for i in range(32):
    stringa = 'py-smallpt3-lr00001-relu-nnx4-maxAction2-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn_relu_maxAction2.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_dqn_relu_maxAction2)


''''
img = []
mse_array_q_relu_2pi = []
for i in range(32):
    stringa = 'scenedqn3-qlearning-32SPP-2pi-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_q_relu_2pi.append((compare_mse(img_as_float(ref_array), img[i])))
#plt.plot(mse_array_q_relu_2pi)
'''

img = []
mse_array_dqn_maxAction2_epochs2 = []
for i in range(32):
    stringa = 'py-smallpt-lr00001-relu-nnx4-maxAction2-epochs2-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn_maxAction2_epochs2.append((compare_mse(img_as_float(ref_array), img[i])))
#plt.plot(mse_array_dqn_maxAction2_epochs2)

img = []
mse_array_q_newaction = []
for i in range(32):
    stringa = 'scenedqn3-qlearning-32SPP-NewAction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_q_newaction.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_q_newaction)

img = []
mse_array_q_newaction2 = []
for i in range(32):
    stringa = 'scenedqn3-qlearning-32SPP-NewAction2-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_q_newaction2.append((compare_mse(img_as_float(ref_array), img[i])))
#plt.plot(mse_array_q_newaction2)

img = []
mse_array_dqn_relu_newAction_maxAction = []
for i in range(32):
    stringa = 'py-smallpt-lr00001-relu-nnx4-newAction-maxAction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn_relu_newAction_maxAction.append((compare_mse(img_as_float(ref_array), img[i])))
#plt.plot(mse_array_dqn_relu_newAction_maxAction)
         
img = []
mse_array_dqn_relu_newAction_maxAction_lr0001 = []
for i in range(27):
    stringa = 'py-smallpt-lr00001-relu-nnx4-newAction-maxAction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn_relu_newAction_maxAction_lr0001.append((compare_mse(img_as_float(ref_array), img[i])))
#plt.plot(mse_array_dqn_relu_newAction_maxAction_lr0001)

img = []
mse_array_dqn_relu_newAction_maxAction_lr000001 = []
for i in range(32):
    stringa = 'py-smallpt-lr000001-relu-nnx4-newAction-maxAction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn_relu_newAction_maxAction_lr000001.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_dqn_relu_newAction_maxAction_lr000001)

img = []
mse_array_dqn_relu_newAction_maxAction_eps5000 = []
for i in range(32):
    stringa = 'py-smallpt-lr00001-relu-nnx4-newAction-maxAction-eps5000-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn_relu_newAction_maxAction_eps5000.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_dqn_relu_newAction_maxAction_eps5000)

img = []
mse_array_DDQM_relu_newAction_maxAction_eps5000_lr00001 = []
for i in range(32):
    stringa = 'py-smallpt-lr00001-relu-nnx4-newAction-maxAction-eps5000-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_DDQM_relu_newAction_maxAction_eps5000_lr00001.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_DDQM_relu_newAction_maxAction_eps5000_lr00001)

img = []
mse_array_relu_newAction_maxAction_eps5000_lr00001_DDQN_struct2 = []
for i in range(20):
    stringa = 'py-smallpt-lr00001-relu-nnx4-newAction-maxAction-eps5000-DDQN_struct2-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_relu_newAction_maxAction_eps5000_lr00001_DDQN_struct2.append((compare_mse(img_as_float(ref_array), img[i])))
#plt.plot(mse_array_relu_newAction_maxAction_eps5000_lr00001_DDQN_struct2)

img = []
mse_array_dqn_relu_newAction_maxAction_eps5000_lr000001 = []
for i in range(28):
    stringa = 'py-smallpt-lr000001-relu-nnx4-newAction-maxAction-eps5000-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn_relu_newAction_maxAction_eps5000_lr000001.append((compare_mse(img_as_float(ref_array), img[i])))
#plt.plot(mse_array_dqn_relu_newAction_maxAction_eps5000_lr000001)

img = []
mse_array_DDQM_relu_newAction_maxAction_eps5000_lr00001_norelu = []
for i in range(16):
    stringa = 'py-smallpt-lr00001-relu-nnx4-newAction-maxAction-eps5000-DDQN_struct2-no_relu-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_DDQM_relu_newAction_maxAction_eps5000_lr00001_norelu.append((compare_mse(img_as_float(ref_array), img[i])))
#plt.plot(mse_array_DDQM_relu_newAction_maxAction_eps5000_lr00001_norelu)

img = []
mse_array_relu_newAction_maxAction_eps5000_lr00001_DDQN_struct4 = []
for i in range(32):
    stringa = 'py-smallpt-lr00001-relu-nnx4-newAction-maxAction-eps5000-DDQN_struct4-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_relu_newAction_maxAction_eps5000_lr00001_DDQN_struct4.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_relu_newAction_maxAction_eps5000_lr00001_DDQN_struct4)

img = []
mse_array_relu_newAction_maxAction_eps5000_lr000001_DDQN_struct4 = []
for i in range(20):
    stringa = 'py-smallpt-lr000001-relu-nnx4-newAction-maxAction-eps5000-DDQN_struct4-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_relu_newAction_maxAction_eps5000_lr000001_DDQN_struct4.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_relu_newAction_maxAction_eps5000_lr000001_DDQN_struct4)

plt.xlabel("SPP",fontweight='bold', fontsize='large')
plt.ylabel("MSE",fontweight='bold', fontsize='large')
plt.legend(["Deep Q-Learning 1000","Q-Learning","Cosine", "Max Action 2", "Q-Learning new action", "DQN newAction maxAction lr000001", "DQN new action eps5000 lr00001", "DDQN eps5000 lr00001","DDQN_struct4 lr00001", "same 0000001"],bbox_to_anchor=(1.04, 1), loc='upper left', ncol=1)

#plt.legend(["Deep Q-Learning 1000","Deep Q-Learning 1500","Q-Learning","Cosine", "Deep Q-Learning Double Kernel","Deep Q-Learning Double Kernel lr000001", "Sigmoid not all", "Decaying 1.8 0.00001"],fontsize='large',bbox_to_anchor=(0, 1), loc='upper left', ncol=1)   
#plt.savefig("scene3-mse.png")
plt.show()

# %% [markdown]
# # SCENE 3 - DQN 1000 VS 1500

# %%
from skimage.measure import compare_ssim, compare_mse
from skimage import img_as_float
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

ref = Image.open('scenedqn3-5120spp-explicit-256.png').convert("RGB")
ref_array = np.array(ref)

img = []
ssim_array_dqn = []
for i in range(32):
    stringa = 'py-smallpt3-10000L2000-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-32spp-256-depth6-noisereduction-AGAIN-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_dqn)

img = []
ssim_array_dqn_1500 = []
for i in range(32):
    stringa = 'py-smallpt-3-10000L2000-72actions-lineareps-lr00001-1500nnx4-KERNEL16-targetnet-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn_1500.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_dqn_1500)


plt.xlabel("SPP", fontweight='bold', fontsize='large')
plt.ylabel("SSIM", fontweight='bold', fontsize='large')
plt.legend(["Deep Q-Learning, 1000 Neurons", "Deeo Q-Learning, 1500 Neurons"],fontsize='large')
plt.savefig("scene3-1000vs1500-ssim.png")

plt.show()


# MSE

img = []
mse_array_dqn = []
for i in range(32):
    stringa = 'py-smallpt3-10000L2000-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-32spp-256-depth6-noisereduction-AGAIN-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_dqn)

img = []
mse_array_dqn_1500 = []
for i in range(32):
    stringa = 'py-smallpt-3-10000L2000-72actions-lineareps-lr00001-1500nnx4-KERNEL16-targetnet-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn_1500.append((compare_mse(img_as_float(ref_array), img[i]))) 
plt.plot(mse_array_dqn_1500)


plt.xlabel("SPP",fontweight='bold', fontsize='large')
plt.ylabel("MSE",fontweight='bold', fontsize='large')
plt.legend(["Deep Q-Learning, 1000 Neurons","Deep Q-Learning, 1500 Neurons"],fontsize='large')   
plt.savefig("scene3-1000vs1500-mse.png")
plt.show()

# %% [markdown]
# # SCENE 1, 128 SPP

# %%
ref = Image.open('scenedqn-5120spp-explicit-256.png').convert("RGB")
ref_array = np.array(ref)

# SSIM -----------------------------------
img = []
ssim_array_dqn = []
for i in range(128):
    stringa = '10000L3500-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-noisereduction-128SPP-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_dqn)

img = []
ssim_array_q = []
for i in range(128):
    stringa = 'scenedqn-qlearning-noisereduction-128SPP-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_q.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_q)



plt.xlabel("SPP", fontweight='bold', fontsize='large')
plt.ylabel("SSIM", fontweight='bold', fontsize='large')
plt.legend(["Deep Q-Learning", "Q-Learning"], fontsize='large')
#plt.savefig("scene1-ssim-targetvsnotarget.png")
plt.show()


# MSE -----------------------------------
img = []
mse_array_dqn = []
for i in range(128):
    stringa = '10000L3500-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-noisereduction-128SPP-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_dqn)


img = []
mse_array_q = []
for i in range(128):
    stringa = 'scenedqn-qlearning-noisereduction-128SPP-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_q.append((compare_mse(img_as_float(ref_array), img[i])))
plt.plot(mse_array_q)


plt.xlabel("SPP", fontweight='bold', size='large')
plt.ylabel("MSE", fontweight='bold', fontsize='large')
plt.legend(["Deep Q-Learning", "Q-Learning"],fontsize='large')
#plt.savefig("scene1-mse-targetvsnotarget.png")
plt.show()

# %% [markdown]
# # SCENE 2, DOUBLE TRAINING

# %%
from skimage.measure import compare_ssim, compare_mse
from skimage import img_as_float
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

ref = Image.open('scenedqn2-5120spp-explicit-256.png').convert("RGB")
ref_array = np.array(ref)

img = []
ssim_array_dqn = []
for i in range(32):
    stringa = '10000L3500-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-128SPP-doubletraining' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_dqn)
print("DQN, SSIM: ", compare_ssim(ref_array, np.array(img[31]), multichannel = True))


img = []
ssim_array_dqn = []
for i in range(32):
    stringa = '10000L2000-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-doubletraining-2-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_dqn.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_dqn)
print("DQN, SSIM: ", compare_ssim(ref_array, np.array(img[31]), multichannel = True))



ssim_array_q = []
img = []
for i in range(32):
    stringa = 'scenedqn2-qlearning-noisereduction-32SPP-doubletraining' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_q.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_q)
print("Q, SSIM: ", compare_ssim(ref_array, np.array(img[31]), multichannel = True))


ssim_array_impsampl = []
img = []
for i in range(32):
    stringa = 'scenedqn2-importancesampling-noisereduction-' + str(i) + '.png'
    img.append((Image.open(stringa)).convert('RGB'))
    ssim_array_impsampl.append((compare_ssim(ref_array, np.array(img[i]), multichannel = True)))
plt.plot(ssim_array_impsampl)


plt.xlabel("SPP", fontweight='bold', fontsize='large')
plt.ylabel("SSIM",fontweight='bold', fontsize='large')
plt.legend(["Deep Q-Learning","Deep Q-Learning double", "Q-Learning","Cosine"],fontsize='large')
plt.savefig("scene2-ssim-doubletraining-2.png")
plt.show()


# MSE

'''
img = []
mse_array_dqn = []
for i in range(32):
    stringa = 'py-smallpt2-10000L2000-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-32spp-256-noisereduction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn.append((compare_mse(img_as_float(ref_array), img_as_float(img[i]))))
plt.plot(mse_array_dqn)
print("DQN, MSE: ",compare_mse(img_as_float(ref_array), img_as_float(img[31])))
'''

img = []
mse_array_dqn = []
for i in range(32):
    stringa = '10000L3500-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-128SPP-doubletraining' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn.append((compare_mse(img_as_float(ref_array), img_as_float(img[i]))))
plt.plot(mse_array_dqn)
print("DQN, MSE: ",compare_mse(img_as_float(ref_array), img_as_float(img[31])))



img = []
mse_array_dqn = []
for i in range(32):
    stringa = '10000L2000-72actions-lineareps-lr00001-1000nnx4-KERNEL16-targetnet-doubletraining-2-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_dqn.append((compare_mse(img_as_float(ref_array), img_as_float(img[i]))))
plt.plot(mse_array_dqn)
print("DQN, MSE: ",compare_mse(img_as_float(ref_array), img_as_float(img[31])))



'''
img = []
mse_array_q = []
for i in range(32):
    stringa = 'scenedqn2-qlearning-noisereduction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_q.append((compare_mse(img_as_float(ref_array), img_as_float(img[i]))))
plt.plot(mse_array_q)
print("Q, MSE: ", compare_mse(img_as_float(ref_array), img_as_float(img[31])))
'''
img = []
mse_array_q = []
for i in range(32):
    stringa = 'scenedqn2-qlearning-noisereduction-32SPP-doubletraining' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_q.append((compare_mse(img_as_float(ref_array), img_as_float(img[i]))))
plt.plot(mse_array_q)
print("Q, MSE: ", compare_mse(img_as_float(ref_array), img_as_float(img[31])))



img = []
mse_array_impsampl = []
for i in range(32):
    stringa = 'scenedqn2-importancesampling-noisereduction-' + str(i) + '.png'
    img.append(img_as_float((Image.open(stringa)).convert('RGB')))
    mse_array_impsampl.append((compare_mse(img_as_float(ref_array), img_as_float(img[i]))))

plt.plot(mse_array_impsampl)
plt.xlabel("SPP", fontweight='bold', fontsize='large')
plt.ylabel("MSE", fontweight='bold', fontsize='large')
plt.legend(["Deep Q-Learning","Deep Q-Learning double", "Q-Learning","Cosine"],fontsize='large')




plt.savefig("scene2-mse-doubletraining-2.png")
plt.show()
# Out:
# DQN, SSIM:  0.08949814507367403
# DQN, SSIM:  0.08529601021231271
# Q, SSIM:  0.0926653448770292
# DQN, MSE:  0.025984373482529754
# DQN, MSE:  0.0265248145651362
# Q, MSE:  0.0210022607021388
